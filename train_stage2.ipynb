# %%
# %run train_stage.py --config ./configs/jupyter_stage2.yaml --checkpoint checkpoints/stage1/sem_moco_stage1_final.pth --stage 2

# %%
# %run train_stage.py --config ./configs/jupyter_stage2.yaml --resume --stage 2
